# %%
"""Hugging_Face 
Hugging Face는 자연어 처리 외에도 여러 transformers 기반 task 분석 모델, 데이터 셋 등을 제공하는 곳이다.

1. from transformers                                        : Hugging Face의 Transformer 모델
    1) import pipeline                                          : 파이프라인
        i) pipeline(task='', model='')
            - tokenizer + model + classifier
    2) import AutoModel                                         : 기본 모델(Encoder) 로드
        i) AutoModel
            - from_pretrained(model='')
            - from_config
        ii) AutoModelTask_Name                                      : 기본 모델 + Classifier 로드 
            - from_pretrained(model='')
        iii) transformers.modeling_outputs
            - last_hidden_state
            - pooler_output
    3) import AutoTokenizer                                     : 기본 모델의 Tokenizer 로드
        i) transformers.tokenization_utils_base.BatchEncoding
            - input_ids
            - token_type_ids
            - attention_mask
    4) import AutoConfig                                        : 기본 모델의 파라미터, 구조 등 로드
    5) import TrainingArguments                                 : 학습 설정
    6) import Trainer                                           : 트레이너 
        - train() | evaluate()

2. from datasets                                            : Hugging Face의 데이터셋
    - load_dataset()
    1) Dataset
        - num_rows | features
        - to_pandas() | from_pandas()
        - shuffle() | select()

3. from tokenizers                                          : Hugging Face의 Tokenizer
    1) import Tokenizer

4. from evaluate                                            : Hugging Face의 Metrics
    1) EvaluationModule
        - compute()

"""
