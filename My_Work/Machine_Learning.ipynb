# %%
'''
정형 데이터를 불러와 여러 전처리 과정을 거친 뒤, 최적 모델과 파라미터를 찾아가는 것이 핵심

1. Data Understanding
    1) sklearn.datasets : 데이터 셋 모음집
    - load_iris
    - load_breast_cancer
    - load_digits
    - fetch_xxxx / make_regression
    2) sklearn.model_selection : 최적의 모델을 찾기 위한 부가적인 방법
    - train_test_split
    - KFold
    - StratifiedKFold
    - cross_val_score
    - cross_validate

    - GridSearchCV : 모델에 파라미터 전달 / 최적화
    - RandomizedSearchCV

2. Data Preparation
    1) sklearn.preprocessing : 타입별 전처리
    - LabelEncoder
    - OneHotEncoder
    - StandardScaler
    - MinMaxScaler
    - PolynomialFeatures
    2) sklearn.feature_extraction
    - sklearn.decomposition.PCA
    3) sklearn.feature_selection
    4) sklearn.impute : 결측치 처리
    - SimpleImputer
    - KNNImputer
    5) sklearn.compose
    - ColumnTransformer : 모델에 컬럼 전달 / 전처리
    - make_column_transformer

3. Modeling
    1) sklearn.linear_model
    - LinearRegression
    - Ridge / Lasso / ElesticNet 
    - LogisticRegression : 이진 분류 모델
    2) sklearn.tree
    - DecisionTreeRegressor
    - DecisionTreeClassifier
    - export_graphviz / graphviz.Source
    3) sklearn.svm
    - SVC
    - SVR
    4) sklearn.ensemble
    - RandomForestRegressor
    - RandomForestClassifier
    - GradientBoostingClassifier
    - GradientBoostingRegressor
    +) xgboost
    - XGBClassifier
    - XGBRegressor
    5) sklearn.neighbors
    - KNeighborsClassifier
    - KNeighborsRegressor
    6) sklearn.cluster
    - KMeans  
    7) sklearn.pipeline
    - Pipeline : 이어붙이기 / 모델링
    - make_pipeline : 소문자를 자동으로 이름으로서 받아들여


4. Evaluation
    1) sklearn.metrics
    - accuracy_score
    - recall_score
    - precision_score
    - f1_score
    - classification_report
    - mean_squared_error
    - root_mean_squared_error
    - r2_score

    - confusion_matrix
    - ConfusionMatrixDisplay
    - precision_recall_curve / PrecisionRecallDisplay / average_precision_score
    - roc_curve / RocCurveDisplay / roc_auc_score

    - silhouette_samples()
    - silhouette_score()
'''
