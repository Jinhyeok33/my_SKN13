# %%
"""Django

1. django.contrib
    1) admin
        - admin.site.register()

2. django.urls
    1) path
    2) include

3. django.http
    1) HttpResponse

4. django.db
    1) models
        i) CharField
        ii) IntegerField
        iii) DateTimeField
        iv) ForeignKey
        v) OneToOneField | ManyToManyField

5. django.shortcuts
    1) render

6. django.utils
    1) timezone
        - now()

7. django.template
    1) loader
"""
