# %%
'''자연어 처리
전체 글을 받아 토큰화를 진행하고, 불용어를 제외시켜 준 뒤, 형태소 분석이 끝나면 이를 벡터에 매핑시킨다.
이 벡터를 가지고 분석하는 것이 자연어 처리이다.

1. 기본 정보
    1) import re                    : 정규표현식
        - compile()
        - match() / search()
        - findall() / finditer()
        - sub() / subn()
    2-1) import nltk.corpus         : 말뭉치 목록_nltk
        - stopwords                 : 불용어 목록
        - wordnet                   : WordNet이 사용하는 품사 목록
    2-2) import konlpy.corpus       : 말뭉치 목록_konlpy
        - kolaw
        - kobill
    2-3) import Korpora             : 말뭉치 목록_한글
        - Korpora
    3) import string                : 문자열 관련
        - punctuation
        
2. Data Preprocessing               : 문자열 전처리 과정
    1) import nltk                  : 토큰화
        - sent_tokenize()
        - word_tokenize()
        - regexp_tokenize()
        - TreebankWordTokenizer.tokenize()
    2) import tokenizers            : 서브워드 토큰화
        - Tokenizer
        i) pre_tokenizers           : 서브워드 전처리
        - Whitespace
        ii) trainers                : Trainer
        - BpeTrainer
        iii) models                 : 토큰화 기기 
        - BPE
        - WordPiece
        - Unigram
            - train()
            - save() / from_file()
            - get_vocab() / get_vocab_size()
    3-1) import nltk.stem           : 형태소 분석_nltk
        i) Stemmer                  : 어간 추출기
        - PorterStemmer
        - LancasterStemmer
        - SnowballStemmer
        ii) Lemmatizer              : 원형 분석기
        - WordNetLemmatizer
    3-2) import konlpy.tag          : 형태소 분석_konlpy
        - Okt
            - morphs()
            - nouns()
            - pos()
        - Kkma
    4) import nltk.tag              : 품사 태깅_nltk
        - pos_tag()
    5-1) LabelEncoding              : 벡터화_LabelEncoding
        - sklearn.preprocessing.LabelEncoder
    5-2) OneHotEncoding             : 벡터화_OneHotEncoding
        - sklearn.preprocessing.OneHotEncoder
    5-3) sklearn.feature_extraction.text    : 벡터화_BoW
        - CountVectorizer           : DTM / TDM
            - vocabulary_
            - get_feature_names_out()
            - fit() / transform()
        - TfidfVectorizer           : TF-IDF

3. Modeling                         : 토큰 분석 과정
    1) import nltk.Text             : 문맥 분석 객체 
        - count()
        - collocations()
        - concordance()
        - plot()
        - dispersion_plot()
        - vocab()
    2) import nltk.FreqDist         : 빈도수 분석 객체
        - B() / N()
        - get()
        - freq()
        - most_common()
    3) import wordcloud.Wordcloud   : 빈도수 시각화 객체
        - generate()
'''
