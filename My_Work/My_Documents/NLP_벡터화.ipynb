# %%
'''자연어 처리_벡터화
단어 사전의 각 단어들을 이제 n차원 벡터에 매핑시킨다.
이렇게 만들어진 Embedding Vector를 가지고 RNN(LSTM, GRU) + Attention 기법을 통해 여러 task별 분석이 가능하다.

1. Count-Based Word Representation                          : 토큰 -> 빈도수 값
    1) Document Term Matrix                                     : Bag of Words_DTM
        i) sklearn.feature_extraction.text.CountVectorizer
            - fit() / transform()
            - vocabulary_
    2) Term Frequency Inverse Document Frequency                : Bag of Words_TF-IDF
        i) sklearn.feature_extraction.text.TfidfVectorizer

2. Word Embedding                                           : 토큰 -> 고정 Vector
    1) One-Hot-Encoding                                         : 원핫인코딩 방식
        i) sklearn.preprocessing.OneHotEncoder
    2) CBoW, Skip-gram                                          : Continuous Bag of Words
        i) gensim.models.Word2Vec
        ii) gensim.models.Word2Vec.wv
            - vectors
            - key_to_index
            - most_similar() / similarity()

3. Contextualized Word Embedding                            : 토큰 -> 동적 Vector






5-1) LabelEncoding              : 벡터화_LabelEncoding
        - sklearn.preprocessing.LabelEncoder
    5-2) OneHotEncoding             : 벡터화_OneHotEncoding
        - sklearn.preprocessing.OneHotEncoder
    5-3) sklearn.feature_extraction.text    : 벡터화_BoW
        i) CountVectorizer          : DTM / TDM
            - vocabulary_
            - get_feature_names_out()
            - fit() / transform()
        ii) TfidfVectorizer         : TF-IDF
'''
