# %%
'''자연어 처리_토큰화
전체 Text를 받아 문장, 단어, 공백, 구두점 등을 기준으로 토큰화를 진행한다.
의미를 담기 위해 어간만을 추출하거나 원형을 복원하는 방법도 존재한다.
더 다양한 의미를 담기 위해 이를 서브워드로 나누어 단어 사전에 등록하는 방법도 존재한다.
이를 통해 단어 사전을 만드는 것이 최종 목표 

1. 기본 정보
    1) import re                    : 정규표현식
        - compile()
        - match() / search()
        - findall() / finditer()
        - sub() / subn()
    2-1) import nltk.corpus         : 말뭉치 목록_nltk
        - stopwords                     : 불용어 목록
        - wordnet                       : WordNet이 사용하는 품사 목록
    2-2) import konlpy.corpus       : 말뭉치 목록_konlpy
        - kolaw
        - kobill
    2-3) import Korpora             : 말뭉치 목록_한글
        - Korpora
    3) import string                : 문자열 관련
        - punctuation

2. NLTK                         : 자연어(영어) 토큰화 라이브러리    
    1) import nltk                  : 기본 토큰화
        - sent_tokenize()
        - word_tokenize()
        - regexp_tokenize()
        - TreebankWordTokenizer.tokenize()
    2) import nltk.stem             : 형태소 분석
        i) Stemmer                      : 어간 추출기
            - PorterStemmer
                - stem()
            - LancasterStemmer
            - SnowballStemmer
        ii) Lemmatizer                  : 원형 분석기
            - WordNetLemmatizer
                - lemmatize()
    3) import nltk.tag              : 품사 태깅
        - pos_tag()

3. KoNLPy                       : 자연어(한국어) 토큰화 라이브러리
    1) import konlpy.tag            : 형태소 분석_konlpy
        i) Okt
            - morphs()
            - nouns()
            - pos()
            - tagset
        ii) Kkma

4. Hugging Face Tokenizer       : 서브워드 토큰화 라이브러리
    - import tokenizers
    1) Tokenizer                    : Pipeline
        - train()
        - save() / from_file()
        - get_vocab() / get_vocab_size()
        - encode() / decode()
        - token_to_id() / id_to_token()
        i) Encoding                     : Encode된 객체 
            - tokens / ids / offsets
    2) tokenizers.pre_tokenizers    : 기본 토큰화
        i) Whitespace
    3) tokenizers.models            : 서브워드 토큰화
        i) BPE
        ii) WordPiece
        iii) Unigram
    4) tokenizers.trainers           : 학습기기
        i) BpeTrainer
        ii) WordPieceTrainer
        iii) UnigramTrainer

5. Modeling                     : 토큰 분석 과정
    1) import nltk.Text             : 문맥 분석 객체 
        - count()
        - collocations()
        - concordance()
        - plot()
        - dispersion_plot()
        - vocab()
    2) import nltk.FreqDist         : 빈도수 분석 객체
        - B() / N()
        - get()
        - freq()
        - most_common()
    3) import wordcloud.Wordcloud   : 빈도수 시각화 객체
        - generate()
'''
