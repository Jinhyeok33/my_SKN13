# %%
'''
많은 데이터를 사용하기에 DataLoader를 사용한다는 점이 머신러닝과 다르며, 여러 Layer를 구성한다는 점도 다르다.
개별 모델을 사용하는 머신러닝과 다르게 전체 구조에 대한 Dataloader, Model Layer, Loss Function과 Optimizer을 구성해준다는 점.

1. Data Understading
    1) torch.utils.data                 : 데이터 관련 클래스
        - DataLoader                        : 데이터 로더 클래스
        - Dataset                           : 데이터셋 클래스                            
    2) torchvision.datasets             : 데이터셋
        - MNIST
        - CIFAR10

2. Data Preprocessing
    1) torchvision.transforms           : 전처리기
        - ToTensor : tensor화, scaling, channel 순서 변경 
        - Compose
        - Normalize
    2) torchaudio / torchtext

3. Modeling
    1) torch.nn                         : 딥러닝 모델 / 활성화 함수 / 평가 함수
        - Linear
        - MSELoss / CrossEntropyLoss
        - ReLU / tanh
        - Module / Squential
    2) torch.optim                      : 딥러닝 옵티마이저
        - SGD
        - Adam
        - RMSprop

4. Evalution
    1) IPython.display              : img 파일 시각화
        - display
    2) import torchinfo
        - summary

5. save & load
    1) torch.save / load
    2) model.state_dict() / model.load_state_dict()
'''
