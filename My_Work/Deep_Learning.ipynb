# %%
'''
많은 데이터를 사용하기에 DataLoader를 사용한다는 점이 머신러닝과 다르며, 여러 Layer를 구성한다는 점도 다르다.
개별 모델을 사용하는 머신러닝과 다르게 전체 구조에 대한 Dataloader, Model Layer, Loss Function과 Optimizer을 구성해준다는 점.

1. Data Understading                : 데이터 관련
    1) torch.utils.data             : 
        - DataLoader
        - Dataset 
    2) torchvision.datasets
        - MNIST
        - CIFAR10
2. Data Preprocessing
    1) torchvision.transforms
        - ToTensor : tensor화, scaling, channel 순서 변경 
        - Compose
        - Normalize

3. Modeling
    1) torch.nn
        - Linear

        - MSELoss
        - CrossEntropyLoss

        - ReLU

        - Module
        - Squential
    2) torch.optim
        - SGD
        - Adam
        - RMSprop

4. Evalution
    1) IPython.display              : img 파일 시각화
        - display
'''
