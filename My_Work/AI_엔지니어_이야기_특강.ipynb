# %%
"""
1. LLM 활용 인공지능 서비스 현업 사례
    - 통계에 기반한 통계적 언어 모델 -> 이전 정보를 받기 시작한 RNN 모델 -> 2017년 구글이 제안한 이전 데이터에 비중을 둔 transformer
    모델 -> 강화학습과 연산량 증가에 따른 Physical AI?
    - AI의 현재 수준 평가 : narrow 수준에서 일부 초지능 달성, "범용 AI" 는?
    - AI를 활용하는 MCP
    - 더욱 더 긴 장기기억 -> 별도 메모리 확보? 
    - BERT(encoder 추출), GPT(decoder 추출), T5(둘 다)
    - Claude, GPT, Gemini
2. LLM 활용 비즈니스 현황
    - 금융, 헬스케어, 제조(화학) 등 특히나 챗봇 모델이 성행
    - 법률 / 의료 집단의 기억력이 위협받음
3. LLM 활용 프로젝트 사례
    1) 상담 센터 대화를 활용한 관리 교사 특성 분석
    2) 상담 센터 대화를 활용한 이탈 예측 모델 개발
4. AI 엔지니어 취업 전략
    - 잡플랜e
    - 정보처리기사 및 마무리 프로젝트 + "특별한" 프로젝트

- notebooklm
- nia nifa
- groq
- aihub
"""
